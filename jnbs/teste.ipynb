# %% [markdown]
#  # Estudo de jupyter usando o VsCode
#  ### Markdown funcionando dentro do jupyter / python interactive
#  Dá pra programar aqui dentro e exportar um estudo completo

# %%
import pandas as pd
df = pd.read_csv("credit-data.csv")

# %%
df.describe()
